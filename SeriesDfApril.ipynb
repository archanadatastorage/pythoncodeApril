# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
from numpy.random import *

# %%
country = ['India','USA', 'UK','China']
population = [6789,2300,452,6756]

# %%
serpop = Series(population)

# %%
population
# Out:
# [6789, 2300, 452, 6756]

# %%
arrpop = np.array(population)

# %%
arrpop
# Out:
# array([6789, 2300,  452, 6756])

# %%
serpop
# Out:
# 0    6789
# 1    2300
# 2     452
# 3    6756
# dtype: int64

# %%
ser1 = Series(population,index=country)

# %%
ser1
# Out:
# India    6789
# USA      2300
# UK        452
# China    6756
# dtype: int64

# %%
'UK' in ser1
# Out:
# True

# %%
'Uk' in ser1
# Out:
# False

# %%
pd.isnull(ser1)
# Out:
# India    False
# USA      False
# UK       False
# China    False
# dtype: bool

# %%
pd.isna(ser1)
# Out:
# India    False
# USA      False
# UK       False
# China    False
# dtype: bool

# %%
pd.notna(ser1)
# Out:
# India    True
# USA      True
# UK       True
# China    True
# dtype: bool

# %%
type(ser1)
# Out:
# pandas.core.series.Series

# %%
nl=pd.read_csv(r'C:\Users\Krishna\data\python_code\nfl.csv')

# %%
ser2 = Series([1,100,'Ram'])

# %%
ser2
# Out:
# 0      1
# 1    100
# 2    Ram
# dtype: object

# %%
ser2[0]
# Out:
# 1

# %%
ser1['UK']
# Out:
# 452

# %%
dic1= {"flowers":1000,"fruits":200,"Sport":150}

# %%
ser3 = Series(dic1)

# %%
ser3
# Out:
# flowers    1000
# fruits      200
# Sport       150
# dtype: int64

# %%
ser3['Sport'] = 600

# %%
ser3
# Out:
# flowers    1000
# fruits      200
# Sport       600
# dtype: int64

# %%
serpop
# Out:
# 0    6789
# 1    2300
# 2     452
# 3    6756
# dtype: int64

# %%
ser2
# Out:
# 0      1
# 1    100
# 2    Ram
# dtype: object

# %%
ser2[2]= 400

# %%
res=serpop +ser2

# %%
type(res)
# Out:
# pandas.core.series.Series

# %%
res
# Out:
# 0    6790
# 1    2400
# 2     852
# 3     NaN
# dtype: object

# %%
res.isna()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %%
nl
# Out:
#     Rank                    Team     GP  Won  Lost Tied[c]   Pct.  First NFL season   Division
# 0      1          Dallas Cowboys    981  562   413   6 (0)  0.576              1960   NFC East
# 1      2       Green Bay Packers  1,435  800   598  38 (8)  0.572              1921  NFC North
# 2      3        Baltimore Ravens    451  256   194       1  0.569              1996  AFC North
# 3      4           Chicago Bears  1,469  793   634  42 (1)  0.556              1920  NFC North
# 4      5    New England Patriots    983  541   433   9 (0)  0.555              1960   AFC East
# 5      6          Miami Dolphins    899  496   399   4 (1)  0.554              1966   AFC East
# 6      7      Kansas City Chiefs    983  532   439  12 (4)  0.548              1960   AFC West
# 7      8       Minnesota Vikings    969  523   435  11 (4)  0.546              1961  NFC North
# 8      9  San Francisco 49ers[b]  1,101  586   501  14 (3)  0.539              1950   NFC West
# ...

# %%
nl.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied[c]', 'Pct.',
#        'First NFL season', 'Division'],
#       dtype='object')

# %%
nfl = pd.read_excel(r'C:\Users\Krishna\data\python_code\nfl.xlsx')

# %%
people = pd.read_json(r'C:\Users\Krishna\data\people.json')

# %%
nfl.head(2)
# Out:
#    Rank               Team    GP  Won  Lost Tied[c]   Pct.  First NFL season   Division
# 0     1     Dallas Cowboys   981  562   413   6 (0)  0.576              1960   NFC East
# 1     2  Green Bay Packers  1435  800   598  38 (8)  0.572              1921  NFC North

# %%
people.head(2)
# Out:
#       name    pcode   age
# 0    Alice  94304.0   NaN
# 1  Brayden  94304.0  30.0

# %%
ppl = pd.read_json(r'C:\Users\Krishna\data\people1.json')

# %%
ppl.columns
# Out:
# Index(['name', 'email', 'city', 'mac', 'timestamp', 'creditcard'], dtype='object')

# %%
ppl.head(3)
# Out:
#                       name                     email  ...                 timestamp           creditcard
# 0             Keeley Bosco  katlyn@jenkinsmaggio.net  ... 2015-04-25 13:57:36+07:00  1228-1221-1221-1431
# 1              Rubye Jerde     juvenal@johnston.name  ... 2015-04-25 09:02:04+07:00  1228-1221-1221-1431
# 2  Miss Darian Breitenberg                      None  ... 2015-04-25 13:16:03+07:00                 None
#
# [3 rows x 6 columns]

# %%
nfl.describe
# Out:
# <bound method NDFrame.describe of     Rank                    Team    GP  Won  Lost Tied[c]   Pct.  First NFL season   Division
# 0      1          Dallas Cowboys   981  562   413   6 (0)  0.576              1960   NFC East
# 1      2       Green Bay Packers  1435  800   598  38 (8)  0.572              1921  NFC North
# 2      3        Baltimore Ravens   451  256   194       1  0.569              1996  AFC North
# 3      4           Chicago Bears  1469  793   634  42 (1)  0.556              1920  NFC North
# 4      5    New England Patriots   983  541   433   9 (0)  0.555              1960   AFC East
# 5      6          Miami Dolphins   899  496   399   4 (1)  0.554              1966   AFC East
# 6      7      Kansas City Chiefs   983  532   439  12 (4)  0.548              1960   AFC West
# 7      8       Minnesota Vikings   969  523   435  11 (4)  0.546              1961  NFC North
# 8      9  San Francisco 49ers[b]  1101  586   501  14 (3)  0.539              1950   NFC West
# ...

# %%
nfl.count()
# Out:
# Rank                32
# Team                32
# GP                  32
# Won                 32
# Lost                32
# Tied[c]             32
# Pct.                32
# First NFL season    32
# Division            32
# dtype: int64

# %%
ppl.count()
# Out:
# name          10000
# email          5002
# city           5070
# mac           10000
# timestamp     10000
# creditcard     5004
# dtype: int64

# %%
ppl.tail()
# Out:
#                     name                       email  ...                 timestamp           creditcard
# 9995  Jaqueline Walter I           payton@glover.biz  ... 2015-04-25 15:21:00+07:00                 None
# 9996      Isobel Reinger          deven@leuschke.org  ... 2015-04-25 16:29:09+07:00  1228-1221-1221-1431
# 9997     Chelsea Shields                        None  ... 2015-04-25 15:46:44+07:00  1211-1221-1234-2201
# 9998     Luciano Gutmann  lindsey_kuvalis@lesch.name  ... 2015-04-25 08:37:19+07:00  1234-2121-1221-1211
# 9999    Austin Langworth   alexys@wilkinsongrady.com  ... 2015-04-25 12:58:27+07:00  1212-1221-1121-1234
#
# [5 rows x 6 columns]

# %%
ppl.columns
# Out:
# Index(['name', 'email', 'city', 'mac', 'timestamp', 'creditcard'], dtype='object')

# %%
nfl.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied[c]', 'Pct.',
#        'First NFL season', 'Division'],
#       dtype='object')

# %%
nfl.loc[31]
# Out:
# Rank                                  32
# Team                Tampa Bay Buccaneers
# GP                                   759
# Won                                  308
# Lost                                 450
# Tied[c]                                1
# Pct.                               0.406
# First NFL season                    1976
# Division                       NFC South
# Name: 31, dtype: object

# %%
ppl[1:2]
# Out:
#           name                  email  city                mac                 timestamp           creditcard
# 1  Rubye Jerde  juvenal@johnston.name  None  90:4d:fa:42:63:a2 2015-04-25 09:02:04+07:00  1228-1221-1221-1431

# %%
ppl[10:21]
# Out:
#                   name                               email  ...                 timestamp           creditcard
# 10        Kris Spencer                                None  ... 2015-04-25 18:49:00+07:00                 None
# 11   Terrance Schiller               prince@rosenbaum.info  ... 2015-04-25 02:25:23+07:00                 None
# 12   Alessandro Barton        sigurd.hudson@hodkiewicz.net  ... 2015-04-25 11:21:45+07:00  1234-2121-1221-1211
# 13      Dr. Art Grimes                   monica@abbott.org  ... 2015-04-25 22:51:21+07:00  1211-1221-1234-2201
# 14         Keven Purdy  carter_zboncak@schmidtjenkins.info  ... 2015-04-25 10:13:00+07:00  1211-1221-1234-2201
# 15  William Wisozk DVM                     adonis@dach.net  ... 2015-04-25 20:57:29+07:00                 None
# 16           Oma Grady       laurianne_goldner@kerluke.biz  ... 2015-04-25 04:08:07+07:00  1212-1221-1121-1234
# ...

# %%
nfl.Team
# Out:
# 0             Dallas Cowboys
# 1          Green Bay Packers
# 2           Baltimore Ravens
# 3              Chicago Bears
# 4       New England Patriots
# 5             Miami Dolphins
# 6         Kansas City Chiefs
# 7          Minnesota Vikings
# 8     San Francisco 49ers[b]
# 9        Pittsburgh Steelers
# 10           New York Giants
# 11     Indianapolis Colts[d]
# 12            Denver Broncos
# 13         Las Vegas Raiders
# 14          Seattle Seahawks
# 15          Los Angeles Rams
# 16      Los Angeles Chargers
# 17       Philadelphia Eagles
# 18     Washington Commanders
# 19    Cleveland Browns[b][e]
# 20          Tennessee Titans
# 21             Buffalo Bills
# 22        New Orleans Saints
# 23         Carolina Panthers
# 24        Cincinnati Bengals
# 25             Detroit Lions
# 26             New York Jets
# 27           Atlanta Falcons
# 28            Houston Texans
# 29      Jacksonville Jaguars
# 30         Arizona Cardinals
# 31      Tampa Bay Buccaneers
# ...

# %%
nfl['Team']
# Out:
# 0             Dallas Cowboys
# 1          Green Bay Packers
# 2           Baltimore Ravens
# 3              Chicago Bears
# 4       New England Patriots
# 5             Miami Dolphins
# 6         Kansas City Chiefs
# 7          Minnesota Vikings
# 8     San Francisco 49ers[b]
# 9        Pittsburgh Steelers
# 10           New York Giants
# 11     Indianapolis Colts[d]
# 12            Denver Broncos
# 13         Las Vegas Raiders
# 14          Seattle Seahawks
# 15          Los Angeles Rams
# 16      Los Angeles Chargers
# 17       Philadelphia Eagles
# 18     Washington Commanders
# 19    Cleveland Browns[b][e]
# 20          Tennessee Titans
# 21             Buffalo Bills
# 22        New Orleans Saints
# 23         Carolina Panthers
# 24        Cincinnati Bengals
# 25             Detroit Lions
# 26             New York Jets
# 27           Atlanta Falcons
# 28            Houston Texans
# 29      Jacksonville Jaguars
# 30         Arizona Cardinals
# 31      Tampa Bay Buccaneers
# ...

# %%
ppl[['name','email','mac']]
# Out:
#                          name                       email                mac
# 0                Keeley Bosco    katlyn@jenkinsmaggio.net  08:fd:0b:cd:77:f7
# 1                 Rubye Jerde       juvenal@johnston.name  90:4d:fa:42:63:a2
# 2     Miss Darian Breitenberg                        None  f9:0e:d3:40:cb:e9
# 3            Celine Ankunding      emery_kunze@rogahn.net  3a:af:c9:0b:5c:08
# 4            Dr. Araceli Lang    mavis_lehner@jacobi.name  9e:ea:28:41:2a:50
# ...                       ...                         ...                ...
# 9995       Jaqueline Walter I           payton@glover.biz  94:45:e0:51:36:7f
# 9996           Isobel Reinger          deven@leuschke.org  65:70:d3:6d:7c:f1
# 9997          Chelsea Shields                        None  44:1b:7d:5e:c4:da
# 9998          Luciano Gutmann  lindsey_kuvalis@lesch.name  c3:03:c2:65:13:fa
# 9999         Austin Langworth   alexys@wilkinsongrady.com  f5:43:f0:3f:8c:36
#
# [10000 rows x 3 columns]

# %%
new_nfl = DataFrame(nfl,columns=['Stadium'])

# %%
new_nfl.columns
# Out:
# Index(['Stadium'], dtype='object')

# %%
nfl.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied[c]', 'Pct.',
#        'First NFL season', 'Division'],
#       dtype='object')

# %%
new_nfl = DataFrame(nfl,columns=['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied[c]', 'Pct.',
       'First NFL season', 'Division','Stadium'])

# %%
new_nfl.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied[c]', 'Pct.',
#        'First NFL season', 'Division', 'Stadium'],
#       dtype='object')

# %%
new_nfl.head(3)
# Out:
#    Rank               Team    GP  Won  Lost Tied[c]   Pct.  First NFL season   Division  Stadium
# 0     1     Dallas Cowboys   981  562   413   6 (0)  0.576              1960   NFC East      NaN
# 1     2  Green Bay Packers  1435  800   598  38 (8)  0.572              1921  NFC North      NaN
# 2     3   Baltimore Ravens   451  256   194       1  0.569              1996  AFC North      NaN

# %%
nfl.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied[c]', 'Pct.',
#        'First NFL season', 'Division'],
#       dtype='object')

# %%
new_nfl['Stadium']='Wankhede'

# %%
new_nfl
# Out:
#     Rank                    Team    GP  Won  Lost Tied[c]   Pct.  First NFL season   Division   Stadium
# 0      1          Dallas Cowboys   981  562   413   6 (0)  0.576              1960   NFC East  Wankhede
# 1      2       Green Bay Packers  1435  800   598  38 (8)  0.572              1921  NFC North  Wankhede
# 2      3        Baltimore Ravens   451  256   194       1  0.569              1996  AFC North  Wankhede
# 3      4           Chicago Bears  1469  793   634  42 (1)  0.556              1920  NFC North  Wankhede
# 4      5    New England Patriots   983  541   433   9 (0)  0.555              1960   AFC East  Wankhede
# 5      6          Miami Dolphins   899  496   399   4 (1)  0.554              1966   AFC East  Wankhede
# 6      7      Kansas City Chiefs   983  532   439  12 (4)  0.548              1960   AFC West  Wankhede
# 7      8       Minnesota Vikings   969  523   435  11 (4)  0.546              1961  NFC North  Wankhede
# ...

# %%
ser = Series(['ASta','BSta'],index=[5,0])

# %%
ser
# Out:
# 5    ASta
# 0    BSta
# dtype: object

# %%
new_nfl['Stadium'] =ser

# %%
new_nfl
# Out:
#     Rank                    Team    GP  Won  Lost Tied[c]   Pct.  First NFL season   Division Stadium
# 0      1          Dallas Cowboys   981  562   413   6 (0)  0.576              1960   NFC East    BSta
# 1      2       Green Bay Packers  1435  800   598  38 (8)  0.572              1921  NFC North     NaN
# 2      3        Baltimore Ravens   451  256   194       1  0.569              1996  AFC North     NaN
# 3      4           Chicago Bears  1469  793   634  42 (1)  0.556              1920  NFC North     NaN
# 4      5    New England Patriots   983  541   433   9 (0)  0.555              1960   AFC East     NaN
# 5      6          Miami Dolphins   899  496   399   4 (1)  0.554              1966   AFC East    ASta
# 6      7      Kansas City Chiefs   983  532   439  12 (4)  0.548              1960   AFC West     NaN
# 7      8       Minnesota Vikings   969  523   435  11 (4)  0.546              1961  NFC North     NaN
# ...

# %%
new_nfl[0:6]
# Out:
#    Rank                  Team    GP  Won  Lost Tied[c]   Pct.  First NFL season   Division Stadium
# 0     1        Dallas Cowboys   981  562   413   6 (0)  0.576              1960   NFC East    BSta
# 1     2     Green Bay Packers  1435  800   598  38 (8)  0.572              1921  NFC North     NaN
# 2     3      Baltimore Ravens   451  256   194       1  0.569              1996  AFC North     NaN
# 3     4         Chicago Bears  1469  793   634  42 (1)  0.556              1920  NFC North     NaN
# 4     5  New England Patriots   983  541   433   9 (0)  0.555              1960   AFC East     NaN
# 5     6        Miami Dolphins   899  496   399   4 (1)  0.554              1966   AFC East    ASta

# %%
new_nfl[['Team','Pct.']]
# Out:
#                       Team   Pct.
# 0           Dallas Cowboys  0.576
# 1        Green Bay Packers  0.572
# 2         Baltimore Ravens  0.569
# 3            Chicago Bears  0.556
# 4     New England Patriots  0.555
# 5           Miami Dolphins  0.554
# 6       Kansas City Chiefs  0.548
# 7        Minnesota Vikings  0.546
# 8   San Francisco 49ers[b]  0.539
# 9      Pittsburgh Steelers  0.537
# 10         New York Giants  0.526
# 11   Indianapolis Colts[d]  0.526
# 12          Denver Broncos  0.522
# 13       Las Vegas Raiders  0.520
# 14        Seattle Seahawks  0.517
# 15        Los Angeles Rams  0.506
# 16    Los Angeles Chargers  0.497
# 17     Philadelphia Eagles  0.495
# 18   Washington Commanders  0.495
# 19  Cleveland Browns[b][e]  0.491
# 20        Tennessee Titans  0.487
# 21           Buffalo Bills  0.486
# 22      New Orleans Saints  0.468
# 23       Carolina Panthers  0.459
# 24      Cincinnati Bengals  0.456
# 25           Detroit Lions  0.455
# ...

# %%
new_nfl[['Team','Pct.']].count()
# Out:
# Team    32
# Pct.    32
# dtype: int64

# %%
new_nfl[0:5],['Team','Pct.']
# Out:
# (   Rank                  Team    GP  Won  Lost Tied[c]   Pct.  First NFL season   Division Stadium
#  0     1        Dallas Cowboys   981  562   413   6 (0)  0.576              1960   NFC East    BSta
#  1     2     Green Bay Packers  1435  800   598  38 (8)  0.572              1921  NFC North     NaN
#  2     3      Baltimore Ravens   451  256   194       1  0.569              1996  AFC North     NaN
#  3     4         Chicago Bears  1469  793   634  42 (1)  0.556              1920  NFC North     NaN
#  4     5  New England Patriots   983  541   433   9 (0)  0.555              1960   AFC East     NaN,
#  ['Team', 'Pct.'])

# %%
new_nfl['Won'] >400
# Out:
# 0      True
# 1      True
# 2     False
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14    False
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20     True
# 21     True
# 22     True
# 23    False
# 24    False
# 25     True
# 26     True
# 27    False
# 28    False
# 29    False
# 30     True
# 31    False
# Name: Won, dtype: bool

# %%
new_nfl.loc[[0,5],['Team','Won']]
# Out:
#              Team  Won
# 0  Dallas Cowboys  562
# 5  Miami Dolphins  496

# %%
nfl.count()
# Out:
# Rank                32
# Team                32
# GP                  32
# Won                 32
# Lost                32
# Tied[c]             32
# Pct.                32
# First NFL season    32
# Division            32
# dtype: int64

# %%
pd.set_option("display.max_columns",5)
pd.set_option('display.max_rows',10)

# %%
nfl
# Out:
#     Rank                  Team  ...  First NFL season   Division
# 0      1        Dallas Cowboys  ...              1960   NFC East
# 1      2     Green Bay Packers  ...              1921  NFC North
# 2      3      Baltimore Ravens  ...              1996  AFC North
# 3      4         Chicago Bears  ...              1920  NFC North
# 4      5  New England Patriots  ...              1960   AFC East
# ..   ...                   ...  ...               ...        ...
# 27    28       Atlanta Falcons  ...              1966  NFC South
# 28    29        Houston Texans  ...              2002  AFC South
# 29    30  Jacksonville Jaguars  ...              1995  AFC South
# 30    31     Arizona Cardinals  ...              1920   NFC West
# 31    32  Tampa Bay Buccaneers  ...              1976  NFC South
#
# [32 rows x 9 columns]

# %%
filt = nfl['Division'].str.contains('NFC North')

# %%
filt
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
#       ...
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# Name: Division, Length: 32, dtype: bool

# %%
filt = nfl['Division'].str.contains('NFC North',na=False)

# %%
filt
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
#       ...
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# Name: Division, Length: 32, dtype: bool

# %%
nfl.loc[filt]
# Out:
#     Rank               Team  ...  First NFL season   Division
# 1      2  Green Bay Packers  ...              1921  NFC North
# 3      4      Chicago Bears  ...              1920  NFC North
# 7      8  Minnesota Vikings  ...              1961  NFC North
# 25    26      Detroit Lions  ...              1930  NFC North
#
# [4 rows x 9 columns]

# %%
filt = nfl['Division'].str.count('NFC North')

# %%
# Out:
#     Rank               Team  ...  First NFL season   Division
# 0      1     Dallas Cowboys  ...              1960   NFC East
# 1      2  Green Bay Packers  ...              1921  NFC North
# 0      1     Dallas Cowboys  ...              1960   NFC East
# 1      2  Green Bay Packers  ...              1921  NFC North
# 0      1     Dallas Cowboys  ...              1960   NFC East
# ..   ...                ...  ...               ...        ...
# 0      1     Dallas Cowboys  ...              1960   NFC East
# 0      1     Dallas Cowboys  ...              1960   NFC East
# 0      1     Dallas Cowboys  ...              1960   NFC East
# 0      1     Dallas Cowboys  ...              1960   NFC East
# 0      1     Dallas Cowboys  ...              1960   NFC East
#
# [32 rows x 9 columns]

# %%
ppl
# Out:
#                          name                       email  ...  \
# 0                Keeley Bosco    katlyn@jenkinsmaggio.net  ...
# 1                 Rubye Jerde       juvenal@johnston.name  ...
# 2     Miss Darian Breitenberg                        None  ...
# 3            Celine Ankunding      emery_kunze@rogahn.net  ...
# 4            Dr. Araceli Lang    mavis_lehner@jacobi.name  ...
# ...                       ...                         ...  ...
# 9995       Jaqueline Walter I           payton@glover.biz  ...
# 9996           Isobel Reinger          deven@leuschke.org  ...
# 9997          Chelsea Shields                        None  ...
# 9998          Luciano Gutmann  lindsey_kuvalis@lesch.name  ...
# 9999         Austin Langworth   alexys@wilkinsongrady.com  ...
#
#                      timestamp           creditcard
# 0    2015-04-25 13:57:36+07:00  1228-1221-1221-1431
# 1    2015-04-25 09:02:04+07:00  1228-1221-1221-1431
# ...

# %%
#sorting on values
ppl.sort_values(by=['name'])
# Out:
#                    name                           email  ...  \
# 1517      Aaliyah Bogan          dina.wuckert@mertz.org  ...
# 1501  Aaliyah Gutkowski                            None  ...
# 5894        Aaron Bauch  jermain_grant@ornvonrueden.org  ...
# 4407    Aaron Bergstrom                 arden@kulas.net  ...
# 8293      Abagail Zieme        esther@littelwaters.info  ...
# ...                 ...                             ...  ...
# 3929         Zora Stamm                            None  ...
# 1983   Zora Trantow DVM                            None  ...
# 982          Zula Boyle                            None  ...
# 7995         Zula Feest                            None  ...
# 177          Zula Morar  mireya.fadel@powlowskiyost.biz  ...
#
#                      timestamp           creditcard
# 1517 2015-04-25 08:05:57+07:00                 None
# 1501 2015-04-25 13:13:53+07:00  1211-1221-1234-2201
# 5894 2015-04-25 05:41:47+07:00                 None
# ...

# %%
ppl.sort_values(by=['name'],ascending=False)
# Out:
#                    name                           email  ...  \
# 177          Zula Morar  mireya.fadel@powlowskiyost.biz  ...
# 7995         Zula Feest                            None  ...
# 982          Zula Boyle                            None  ...
# 1983   Zora Trantow DVM                            None  ...
# 3929         Zora Stamm                            None  ...
# ...                 ...                             ...  ...
# 8293      Abagail Zieme        esther@littelwaters.info  ...
# 4407    Aaron Bergstrom                 arden@kulas.net  ...
# 5894        Aaron Bauch  jermain_grant@ornvonrueden.org  ...
# 1501  Aaliyah Gutkowski                            None  ...
# 1517      Aaliyah Bogan          dina.wuckert@mertz.org  ...
#
#                      timestamp           creditcard
# 177  2015-04-25 07:54:09+07:00                 None
# 7995 2015-04-25 13:14:37+07:00                 None
# 982  2015-04-25 01:53:03+07:00  1211-1221-1234-2201
# ...

# %%
nfl
# Out:
#     Rank                  Team  ...  First NFL season   Division
# 0      1        Dallas Cowboys  ...              1960   NFC East
# 1      2     Green Bay Packers  ...              1921  NFC North
# 2      3      Baltimore Ravens  ...              1996  AFC North
# 3      4         Chicago Bears  ...              1920  NFC North
# 4      5  New England Patriots  ...              1960   AFC East
# ..   ...                   ...  ...               ...        ...
# 27    28       Atlanta Falcons  ...              1966  NFC South
# 28    29        Houston Texans  ...              2002  AFC South
# 29    30  Jacksonville Jaguars  ...              1995  AFC South
# 30    31     Arizona Cardinals  ...              1920   NFC West
# 31    32  Tampa Bay Buccaneers  ...              1976  NFC South
#
# [32 rows x 9 columns]

# %%
nfl.sort_values(by=['First NFL season','Team'])
# Out:
#     Rank                  Team  ...  First NFL season   Division
# 30    31     Arizona Cardinals  ...              1920   NFC West
# 3      4         Chicago Bears  ...              1920  NFC North
# 1      2     Green Bay Packers  ...              1921  NFC North
# 10    11       New York Giants  ...              1925   NFC East
# 25    26         Detroit Lions  ...              1930  NFC North
# ..   ...                   ...  ...               ...        ...
# 31    32  Tampa Bay Buccaneers  ...              1976  NFC South
# 23    24     Carolina Panthers  ...              1995  NFC South
# 29    30  Jacksonville Jaguars  ...              1995  AFC South
# 2      3      Baltimore Ravens  ...              1996  AFC North
# 28    29        Houston Texans  ...              2002  AFC South
#
# [32 rows x 9 columns]

# %%
nfl.sort_values(by=['First NFL season','Team'],ascending=[True,False])
# Out:
#     Rank                  Team  ...  First NFL season   Division
# 3      4         Chicago Bears  ...              1920  NFC North
# 30    31     Arizona Cardinals  ...              1920   NFC West
# 1      2     Green Bay Packers  ...              1921  NFC North
# 10    11       New York Giants  ...              1925   NFC East
# 25    26         Detroit Lions  ...              1930  NFC North
# ..   ...                   ...  ...               ...        ...
# 14    15      Seattle Seahawks  ...              1976   NFC West
# 29    30  Jacksonville Jaguars  ...              1995  AFC South
# 23    24     Carolina Panthers  ...              1995  NFC South
# 2      3      Baltimore Ravens  ...              1996  AFC North
# 28    29        Houston Texans  ...              2002  AFC South
#
# [32 rows x 9 columns]

# %%
nfl.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied[c]', 'Pct.',
#        'First NFL season', 'Division'],
#       dtype='object')

# %%
nfl["Won"].max()
# Out:
# 800

# %%
nfl.sort_values(by=['Won'],ascending=False)['Won']
# Out:
# 1     800
# 3     793
# 10    721
# 9     671
# 18    629
#      ...
# 31    308
# 2     256
# 23    214
# 29    198
# 28    152
# Name: Won, Length: 32, dtype: int64

# %%
nfl['Won'].min()
# Out:
# 152

# %%
nfl['Won'].nlargest(5)
# Out:
# 1     800
# 3     793
# 10    721
# 9     671
# 18    629
# Name: Won, dtype: int64

# %%
nfl['Won'].nsmallest(5)
# Out:
# 28    152
# 29    198
# 23    214
# 2     256
# 31    308
# Name: Won, dtype: int64

# %%
nfl.nlargest(5,'Won')
# Out:
#     Rank                   Team  ...  First NFL season   Division
# 1      2      Green Bay Packers  ...              1921  NFC North
# 3      4          Chicago Bears  ...              1920  NFC North
# 10    11        New York Giants  ...              1925   NFC East
# 9     10    Pittsburgh Steelers  ...              1933  AFC North
# 18    19  Washington Commanders  ...              1932   NFC East
#
# [5 rows x 9 columns]

# %%
nfl.nsmallest(5,'Won')
# Out:
#     Rank                  Team  ...  First NFL season   Division
# 28    29        Houston Texans  ...              2002  AFC South
# 29    30  Jacksonville Jaguars  ...              1995  AFC South
# 23    24     Carolina Panthers  ...              1995  NFC South
# 2      3      Baltimore Ravens  ...              1996  AFC North
# 31    32  Tampa Bay Buccaneers  ...              1976  NFC South
#
# [5 rows x 9 columns]

# %%
nfl.count()
# Out:
# Rank                32
# Team                32
# GP                  32
# Won                 32
# Lost                32
# Tied[c]             32
# Pct.                32
# First NFL season    32
# Division            32
# dtype: int64

# %%
nfl['Won'].median()
# Out:
# 510.0

# %%
nfl.median()
# Out:
# C:\Users\Krishna\AppData\Local\Temp\ipykernel_18688\2527375734.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   nfl.median()
# Rank                  16.5000
# GP                   983.0000
# Won                  510.0000
# Lost                 495.0000
# Pct.                   0.5015
# First NFL season    1960.0000
# dtype: float64

# %%
nfl.describe()
# Out:
#             Rank           GP  ...       Pct.  First NFL season
# count  32.000000    32.000000  ...  32.000000         32.000000
# mean   16.500000   999.656250  ...   0.500500       1956.625000
# std     9.380832   292.098261  ...   0.049226         22.511287
# min     1.000000   355.000000  ...   0.406000       1920.000000
# 25%     8.750000   891.750000  ...   0.458250       1936.000000
# 50%    16.500000   983.000000  ...   0.501500       1960.000000
# 75%    24.250000  1243.250000  ...   0.540750       1966.250000
# max    32.000000  1469.000000  ...   0.576000       2002.000000
#
# [8 rows x 6 columns]

# %%
nfl['Division'].value_counts()
# Out:
# NFC East     4
# NFC North    4
# AFC North    4
# AFC East     4
# AFC West     4
# NFC West     4
# AFC South    4
# NFC South    4
# Name: Division, dtype: int64

# %%
ppl.columns
# Out:
# Index(['name', 'email', 'city', 'mac', 'timestamp', 'creditcard'], dtype='object')

# %%
ppl['city'].value_counts()
# Out:
# Emardland               3
# Borerside               3
# Trompbury               3
# Swaniawskimouth         3
# Lake River              3
#                        ..
# East Davon              1
# Port Adeline            1
# South Alexandremouth    1
# East Ardenstad          1
# Lake Jammie             1
# Name: city, Length: 4927, dtype: int64

# %%
ser1
# Out:
# India    6789
# USA      2300
# UK        452
# China    6756
# dtype: int64

# %%
ser1.drop("UK")
# Out:
# India    6789
# USA      2300
# China    6756
# dtype: int64

# %%
ser1
# Out:
# India    6789
# USA      2300
# UK        452
# China    6756
# dtype: int64

# %%
ppl
# Out:
#                          name                       email  ...  \
# 0                Keeley Bosco    katlyn@jenkinsmaggio.net  ...
# 1                 Rubye Jerde       juvenal@johnston.name  ...
# 2     Miss Darian Breitenberg                        None  ...
# 3            Celine Ankunding      emery_kunze@rogahn.net  ...
# 4            Dr. Araceli Lang    mavis_lehner@jacobi.name  ...
# ...                       ...                         ...  ...
# 9995       Jaqueline Walter I           payton@glover.biz  ...
# 9996           Isobel Reinger          deven@leuschke.org  ...
# 9997          Chelsea Shields                        None  ...
# 9998          Luciano Gutmann  lindsey_kuvalis@lesch.name  ...
# 9999         Austin Langworth   alexys@wilkinsongrady.com  ...
#
#                      timestamp           creditcard
# 0    2015-04-25 13:57:36+07:00  1228-1221-1221-1431
# 1    2015-04-25 09:02:04+07:00  1228-1221-1221-1431
# ...

# %%
ppl.columns
# Out:
# Index(['name', 'email', 'city', 'mac', 'timestamp', 'creditcard'], dtype='object')

# %%
ppldrop=ppl.drop('mac',axis=1)

# %%
ppldrop.columns
# Out:
# Index(['name', 'email', 'city', 'timestamp', 'creditcard'], dtype='object')

# %%
ppl.drop(3)
# Out:
#                          name                       email  ...  \
# 0                Keeley Bosco    katlyn@jenkinsmaggio.net  ...
# 1                 Rubye Jerde       juvenal@johnston.name  ...
# 2     Miss Darian Breitenberg                        None  ...
# 4            Dr. Araceli Lang    mavis_lehner@jacobi.name  ...
# 5                 Esteban Von                        None  ...
# ...                       ...                         ...  ...
# 9995       Jaqueline Walter I           payton@glover.biz  ...
# 9996           Isobel Reinger          deven@leuschke.org  ...
# 9997          Chelsea Shields                        None  ...
# 9998          Luciano Gutmann  lindsey_kuvalis@lesch.name  ...
# 9999         Austin Langworth   alexys@wilkinsongrady.com  ...
#
#                      timestamp           creditcard
# 0    2015-04-25 13:57:36+07:00  1228-1221-1221-1431
# 1    2015-04-25 09:02:04+07:00  1228-1221-1221-1431
# ...

# %%
ppl.describe()
# Out:
# C:\Users\Krishna\AppData\Local\Temp\ipykernel_18688\395290871.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   ppl.describe()
#                name                     email  ...                  timestamp  \
# count         10000                      5002  ...                      10000
# unique         9983                      5002  ...                       9445
# top     Joany Blick  katlyn@jenkinsmaggio.net  ...  2015-04-25 15:51:34+07:00
# freq              2                         1  ...                          3
# first           NaN                       NaN  ...  2015-04-25 00:00:03+07:00
# last            NaN                       NaN  ...  2015-04-25 23:59:58+07:00
#
#                  creditcard
# count                  5004
# unique                    4
# ...

# %%
df = DataFrame(randn(25).reshape((5,5)),index=['A','B','D','E','F'],columns=['col1','col2','col3','col4','col5'])

# %%
df
# Out:
#        col1      col2      col3      col4      col5
# A -0.073559  0.696417  1.722605 -0.380196  0.540245
# B  0.899385  0.306678 -0.035450 -1.570322 -0.188606
# D -0.128243 -1.031965 -1.559353  0.626572 -0.152872
# E -1.569877 -0.430325 -1.551821 -0.508034 -0.192097
# F -1.084817  0.060874 -1.628777  1.182070 -0.313341

# %%
df2=df.reindex(['A','B','C','D','E','F'])

# %%
df2
# Out:
#        col1      col2      col3      col4      col5
# A -0.073559  0.696417  1.722605 -0.380196  0.540245
# B  0.899385  0.306678 -0.035450 -1.570322 -0.188606
# C       NaN       NaN       NaN       NaN       NaN
# D -0.128243 -1.031965 -1.559353  0.626572 -0.152872
# E -1.569877 -0.430325 -1.551821 -0.508034 -0.192097
# F -1.084817  0.060874 -1.628777  1.182070 -0.313341

# %%
people
# Out:
#       name    pcode   age
# 0    Alice  94304.0   NaN
# 1  Brayden  94304.0  30.0
# 2    Carla  10036.0  19.0
# 3    Diana      NaN  46.0
# 4  Etienne  94104.0   NaN

# %%
people.describe()
# Out:
#               pcode        age
# count      4.000000   3.000000
# mean   73187.000000  31.666667
# std    42100.772234  13.576941
# min    10036.000000  19.000000
# 25%    73087.000000  24.500000
# 50%    94204.000000  30.000000
# 75%    94304.000000  38.000000
# max    94304.000000  46.000000

# %%
people.dropna()
# Out:
#       name    pcode   age
# 1  Brayden  94304.0  30.0
# 2    Carla  10036.0  19.0

# %%
people
# Out:
#       name    pcode   age
# 0    Alice  94304.0   NaN
# 1  Brayden  94304.0  30.0
# 2    Carla  10036.0  19.0
# 3    Diana      NaN  46.0
# 4  Etienne  94104.0   NaN

# %%
people.dropna(axis=1)
# Out:
#       name
# 0    Alice
# 1  Brayden
# 2    Carla
# 3    Diana
# 4  Etienne

# %%
people.dropna(thresh=2)
# Out:
#       name    pcode   age
# 0    Alice  94304.0   NaN
# 1  Brayden  94304.0  30.0
# 2    Carla  10036.0  19.0
# 3    Diana      NaN  46.0
# 4  Etienne  94104.0   NaN

# %%
people.fillna(20)
# Out:
#       name    pcode   age
# 0    Alice  94304.0  20.0
# 1  Brayden  94304.0  30.0
# 2    Carla  10036.0  19.0
# 3    Diana     20.0  46.0
# 4  Etienne  94104.0  20.0

# %%
people
# Out:
#       name    pcode   age
# 0    Alice  94304.0   NaN
# 1  Brayden  94304.0  30.0
# 2    Carla  10036.0  19.0
# 3    Diana      NaN  46.0
# 4  Etienne  94104.0   NaN

# %%
people.ffill()
# Out:
#       name    pcode   age
# 0    Alice  94304.0   NaN
# 1  Brayden  94304.0  30.0
# 2    Carla  10036.0  19.0
# 3    Diana  10036.0  46.0
# 4  Etienne  94104.0  46.0

# %%
people.backfill()
# Out:
#       name    pcode   age
# 0    Alice  94304.0  30.0
# 1  Brayden  94304.0  30.0
# 2    Carla  10036.0  19.0
# 3    Diana  94104.0  46.0
# 4  Etienne  94104.0   NaN

# %%
people[people['age']>40]
# Out:
#     name  pcode   age
# 3  Diana    NaN  46.0

# %%
nfl[nfl[ "Won"]>500| & nfl['Lost']<500 ]
# Out:
#   File "C:\Users\Krishna\AppData\Local\Temp\ipykernel_18688\1989800737.py", line 1
#     nfl[nfl[ "Won"]>500| & nfl['Lost']<500 ]
#                          ^
# SyntaxError: invalid syntax

# %%
people.dropna(how='all')
# Out:
#       name    pcode   age
# 0    Alice  94304.0   NaN
# 1  Brayden  94304.0  30.0
# 2    Carla  10036.0  19.0
# 3    Diana      NaN  46.0
# 4  Etienne  94104.0   NaN

# %%
df2.dropna(how='all')
# Out:
#        col1      col2      col3      col4      col5
# A -0.073559  0.696417  1.722605 -0.380196  0.540245
# B  0.899385  0.306678 -0.035450 -1.570322 -0.188606
# D -0.128243 -1.031965 -1.559353  0.626572 -0.152872
# E -1.569877 -0.430325 -1.551821 -0.508034 -0.192097
# F -1.084817  0.060874 -1.628777  1.182070 -0.313341

# %%
nfl.corr()
# Out:
#                       Rank        GP  ...      Pct.  First NFL season
# Rank              1.000000 -0.273127  ... -0.992519          0.252046
# GP               -0.273127  1.000000  ...  0.288465         -0.995729
# Won              -0.532235  0.954629  ...  0.544318         -0.944404
# Lost              0.049588  0.941241  ... -0.030448         -0.941148
# Pct.             -0.992519  0.288465  ...  1.000000         -0.266214
# First NFL season  0.252046 -0.995729  ... -0.266214          1.000000
#
# [6 rows x 6 columns]

# %%
nfl.aggregate({"Lost":min})
# Out:
# Lost    194
# dtype: int64

# %%
nfl.aggregate({"Won":["min","max","count"]})
# Out:
#        Won
# min    152
# max    800
# count   32

# %%
nfl.aggregate({"Won":["min","max","mean"],"Lost":["min","max","mean"]})
# Out:
#             Won       Lost
# min   152.00000  194.00000
# max   800.00000  803.00000
# mean  497.65625  488.84375
